# %% [markdown]
# <a href="https://colab.research.google.com/github/moses-irudayaraj/OIBSIP/blob/main/Task2_Unemployment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Essential Libraries

# %%
import numpy as np
import pandas as pd
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Analysing Unemployment in India.csv data file

# %%
db= pd.read_csv('Unemployment in India.csv')
db
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
db.tail(10)
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 758    NaN   NaN        NaN                               NaN
# 759    NaN   NaN        NaN                               NaN
# 760    NaN   NaN        NaN                               NaN
# 761    NaN   NaN        NaN                               NaN
# 762    NaN   NaN        NaN                               NaN
# 763    NaN   NaN        NaN                               NaN
# 764    NaN   NaN        NaN                               NaN
# 765    NaN   NaN        NaN                               NaN
# 766    NaN   NaN        NaN                               NaN
# 767    NaN   NaN        NaN                               NaN
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Area
# 758                  NaN                                       NaN  NaN
# 759                  NaN                                       NaN  NaN
# ...

# %%
db.tail(20)
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 748  West Bengal   31-01-2020    Monthly                              7.27
# 749  West Bengal   29-02-2020    Monthly                              7.55
# 750  West Bengal   31-03-2020    Monthly                              6.67
# 751  West Bengal   30-04-2020    Monthly                             15.63
# 752  West Bengal   31-05-2020    Monthly                             15.22
# 753  West Bengal   30-06-2020    Monthly                              9.86
# 754          NaN          NaN        NaN                               NaN
# 755          NaN          NaN        NaN                               NaN
# 756          NaN          NaN        NaN                               NaN
# 757          NaN          NaN        NaN                               NaN
# 758          NaN          NaN        NaN                               NaN
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
db = db.dropna()

# %%
db
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
db.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
db['Region'].value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
db['Area'].value_counts()
# Out:
# Urban    381
# Rural    359
# Name: Area, dtype: int64

# %%
db.shape
# Out:
# (740, 7)

# %%
db.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
columns_new_name = {
    'Region': 'Region',
    ' Date': 'Date',
    ' Frequency': 'Frequency',
    ' Estimated Unemployment Rate (%)': 'Estimated_Unemployment_Rate_(%)',
    ' Estimated Employed': 'Estimated_Employed',
    ' Estimated Labour Participation Rate (%)': 'Estimated_Labour_Participation_Rate_(%)',
    ' Area': 'Area'
}

db.rename(columns=columns_new_name, inplace=True)

db.columns
# Out:
# <ipython-input-37-731cdac4166d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db.rename(columns=columns_new_name, inplace=True)
# Index(['Region', 'Date', 'Frequency', 'Estimated_Unemployment_Rate_(%)',
#        'Estimated_Employed', 'Estimated_Labour_Participation_Rate_(%)',
#        'Area'],
#       dtype='object')

# %%
db
# Out:
#              Region         Date Frequency  Estimated_Unemployment_Rate_(%)  \
# 0    Andhra Pradesh   31-05-2019   Monthly                             3.65
# 1    Andhra Pradesh   30-06-2019   Monthly                             3.05
# 2    Andhra Pradesh   31-07-2019   Monthly                             3.75
# 3    Andhra Pradesh   31-08-2019   Monthly                             3.32
# 4    Andhra Pradesh   30-09-2019   Monthly                             5.17
# ..              ...          ...       ...                              ...
# 749     West Bengal   29-02-2020   Monthly                             7.55
# 750     West Bengal   31-03-2020   Monthly                             6.67
# 751     West Bengal   30-04-2020   Monthly                            15.63
# 752     West Bengal   31-05-2020   Monthly                            15.22
# 753     West Bengal   30-06-2020   Monthly                             9.86
#
# ...

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    object
#  2   Frequency                                740 non-null    object
#  3   Estimated_Unemployment_Rate_(%)          740 non-null    float64
#  4   Estimated_Employed                       740 non-null    float64
#  5   Estimated_Labour_Participation_Rate_(%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
db['Date'] = db['Date'].astype('datetime64')
# Out:
# <ipython-input-40-74b54c0e24fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['Date'] = db['Date'].astype('datetime64')

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    datetime64[ns]
#  2   Frequency                                740 non-null    object
#  3   Estimated_Unemployment_Rate_(%)          740 non-null    float64
#  4   Estimated_Employed                       740 non-null    float64
#  5   Estimated_Labour_Participation_Rate_(%)  740 non-null    float64
#  6   Area                                     740 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 46.2+ KB

# %%
db['year']=db['Date'].dt.isocalendar().year
db['month']=db['Date'].dt.month
# Out:
# <ipython-input-42-102ccf8c7563>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['year']=db['Date'].dt.isocalendar().year
# <ipython-input-42-102ccf8c7563>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   db['month']=db['Date'].dt.month

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 740 entries, 0 to 753
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   740 non-null    object
#  1   Date                                     740 non-null    datetime64[ns]
#  2   Frequency                                740 non-null    object
#  3   Estimated_Unemployment_Rate_(%)          740 non-null    float64
#  4   Estimated_Employed                       740 non-null    float64
#  5   Estimated_Labour_Participation_Rate_(%)  740 non-null    float64
#  6   Area                                     740 non-null    object
#  7   year                                     740 non-null    UInt32
#  8   month                                    740 non-null    int64
# dtypes: UInt32(1), datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 55.6+ KB

# %%
plt.figure(figsize=(9,7.5))
sns.heatmap(db.corr(),annot=True)
# Out:
# <ipython-input-44-258c0b7703bb>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(db.corr(),annot=True)
# <Axes: >

# %%
plt.bar(db['Area'].unique(),db['Area'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie(db["Region"].value_counts(),labels=db['Region'].unique());

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for i in db['Region'].unique():
    region_data = db[db['Region'] == i]
    plt.figure(figsize=(10, 7))

    # Create a KDE plot for the 'Estimated Unemployment Rate(%)' column with integer year values on the x-axis
    sns.kdeplot(region_data['Estimated_Unemployment_Rate_(%)'], shade=True)

    plt.title(f'KDE Plot for Region {i}')
    plt.ylabel('Density')
    plt.xlabel('Estimated Unemployment Rate(%)')
    plt.grid(True)  # Add gridlines
    plt.show()
# Out:
# <ipython-input-88-145b09f700f2>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(region_data['Estimated_Unemployment_Rate_(%)'], shade=True)
# <ipython-input-88-145b09f700f2>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(region_data['Estimated_Unemployment_Rate_(%)'], shade=True)
# <ipython-input-88-145b09f700f2>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(region_data['Estimated_Unemployment_Rate_(%)'], shade=True)
# <ipython-input-88-145b09f700f2>:9: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# ...

# %%
count_by_region=db['Region'].value_counts().rename_axis('State').reset_index(name='Count')
count_by_region.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_335f5_row0_col1, #T_335f5_row1_col1, #T_335f5_row2_col1, #T_335f5_row3_col1, #T_335f5_row4_col1, #T_335f5_row5_col1, #T_335f5_row6_col1, #T_335f5_row7_col1, #T_335f5_row8_col1, #T_335f5_row9_col1, #T_335f5_row10_col1, #T_335f5_row11_col1, #T_335f5_row12_col1, #T_335f5_row13_col1, #T_335f5_row14_col1, #T_335f5_row15_col1, #T_335f5_row16_col1, #T_335f5_row17_col1, #T_335f5_row18_col1, #T_335f5_row19_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_335f5_row20_col1, #T_335f5_row21_col1 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_335f5_row22_col1, #T_335f5_row23_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_335f5_row24_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_335f5_row25_col1 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_335f5_row26_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_335f5_row27_col1 {
#   background-color: #f7fbff;
# ...

# %%
plt.figure(figsize=(10, 8))
plt.scatter(db['Estimated_Employed'], db['Estimated_Labour_Participation_Rate_(%)'], alpha=0.5)
plt.xlabel('Estimated Employed')
plt.ylabel('Estimated Labour Participation Rate (%)')
plt.title('Estimated Employed vs. Estimated Labour Participation Rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.title('Unemployment Rate based on Area')
sns.scatterplot(y=db['Region'],x=db['Estimated_Unemployment_Rate_(%)'],hue=db['Area'])
# Out:
# <Axes: title={'center': 'Unemployment Rate based on Area'}, xlabel='Estimated_Unemployment_Rate_(%)', ylabel='Region'>

# %%
# Filter data where Estimated_Unemployment_Rate_(%) is greater than 50%
filtered_data = db[db['Estimated_Unemployment_Rate_(%)'] > 50]

# Count the occurrences of each region
region_counts = filtered_data['Region'].value_counts()

# Create the bar graph with custom styling
plt.figure(figsize=(10, 6))  # Set the figure size for better visibility
bars = plt.bar(region_counts.index, region_counts, color='skyblue')  # Customizing bar color

# Adding data labels above each bar within the graph boundaries
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height(), str(int(bar.get_height())), fontsize=12, color='black')

plt.title('Unemployment Rate by Region (Rate > 50%)')
plt.xlabel('Region')
plt.ylabel('Count')
plt.tight_layout()  # Ensures a clean layout
plt.show()

# %%
# Pairplot to visualize relationships between numerical columns by Area
plt.figure(figsize=(12, 10))
sns.pairplot(data=db, vars=['Estimated_Unemployment_Rate_(%)', 'Estimated_Employed', 'Estimated_Labour_Participation_Rate_(%)'], hue='Area')
plt.suptitle('Pairplot of Numerical Columns by Area', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Unemployment_Rate_upto_11_2020.csv Analysis

# %%
db_2 = pd.read_csv('Unemployment_Rate_upto_11_2020.csv')
db_2
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
db_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
db_2[' Date'] = db_2[' Date'].astype('datetime64')

# %%
db_2['year'] = db_2[' Date'].dt.isocalendar().year
db_2['month'] = db_2[' Date'].dt.month

# %%
import plotly.express as px
unemployment = db_2[['Region', 'Region.1', ' Estimated Unemployment Rate (%)', ' Estimated Employed', ' Estimated Labour Participation Rate (%)']]
unemployment = unemployment.groupby(['Region.1', 'Region'])[' Estimated Unemployment Rate (%)'].mean().reset_index()
fig = px.sunburst(unemployment, path=['Region.1', 'Region'], values=' Estimated Unemployment Rate (%)', title='Unemployment rate in each State and Region',height=850)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import calendar
import plotly.express as px

# Convert month to integer and get month abbreviation
db_2['Month_int'] = db_2['month'].apply(lambda x: int(x))
db_2['Month_name'] = db_2['Month_int'].apply(lambda x: calendar.month_abbr[x])

# Create the animated bar plot
fig = px.bar(
    db_2,
    x='Region',
    y=' Estimated Unemployment Rate (%)',
    animation_frame='Month_name',
    color='Region',
    title='Unemployment Rate Across Regions (Jan. 2020 - Oct. 2020)',
    height=600,
    width=1000,
    template='plotly_dark',  # Dark background template
    labels=[' Estimated Unemployment Rate (%)'],  # Rename y-axis label
)

# Customizing the layout
fig.update_layout(
    xaxis_title='Region',  # X-axis label
    yaxis_title=' Estimated Unemployment Rate (%)',  # Y-axis label
    xaxis={'categoryorder': 'total descending'},
    uniformtext_minsize=8,  # Minimum font size for text labels
    uniformtext_mode='hide',  # Hide text labels if too many
)

# Customizing the color scale
fig.update_traces(marker_line_color='white', marker_line_width=0.5, opacity=0.8)

# Set animation duration
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 1000  # Faster animation

# Show the improved plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
